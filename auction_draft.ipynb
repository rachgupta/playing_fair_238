# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set number of agents and budget
N = 4
B = 1000

# %%
# import player data

df = pd.read_csv("player_pts_updated.csv")
df = df.rename(columns={'Total Points': 'True Value', 'std': 'STD', 'Pos': 'Position'})

df.head()
# Out:
#                Player Position  True Value    STD  ID
# 0  Patrick Mahomes II       QB       428.4   8.53   0
# 1          Josh Allen       QB       412.2  10.03   1
# 2         Jalen Hurts       QB       384.0  11.93   2
# 3          Joe Burrow       QB       369.0   9.35   3
# 4          Geno Smith       QB       314.9   6.97   4

# %%
# Generating auction subset: take subset of dataset to take only the top players from each position

# create a new dataframe for each position
df_rb = df[df['Position'] == 'RB'].head(N*4)
df_qb = df[df['Position'] == 'QB'].head(N*2)
df_wr = df[df['Position'] == 'WR'].head(N*4)
df_te = df[df['Position'] == 'TE'].head(N*2)
df_k = df[df['Position'] == 'K'].head(N*2)
df_dst = df[df['Position'] == 'DST'].head(N*2)

df_auction = pd.concat([df_qb, df_rb, df_wr, df_k, df_dst, df_te])
# sort df_auction by descending order of true value
df_auction = df_auction.sort_values(by=['True Value'], ascending=False)
df_auction.head()
# Out:
#                Player Position  True Value    STD  ID
# 0  Patrick Mahomes II       QB       428.4   8.53   0
# 1          Josh Allen       QB       412.2  10.03   1
# 2         Jalen Hurts       QB       384.0  11.93   2
# 3          Joe Burrow       QB       369.0   9.35   3
# 4          Geno Smith       QB       314.9   6.97   4

# %%
# Convert true values, standard devs to numpy array
trueValues = df_auction['True Value'].to_numpy()
stds = df_auction['STD'].to_numpy()

def value_generator(df):
    '''df --> dict: generates a random value for each player,
        then returns the perceived values as a dictionary'''
    perceivedValues = {}
    for i in range(len(df)):
        perceivedValues[df.iloc[i]['ID']] = np.random.normal(trueValues[i], stds[i])
    return perceivedValues

# %%
# Define fair values for each position

v_qb = df_qb['True Value'].sum() / (N)
v_rb = df_rb['True Value'].sum() / (N)
v_wr = df_wr['True Value'].sum() / (N)
v_te = df_te['True Value'].sum() / (N)
v_k = df_k['True Value'].sum() / (N)
v_dst = df_dst['True Value'].sum() / (N)

V = v_qb + v_rb + v_wr + v_te + v_k + v_dst

# %%
# Actual auction simulation

# generate values for each player
player_values = [value_generator(df_auction) for _ in range(N)]
player_selections = [[] for _ in range(N)]

# keep track of how many of each position each player selected
player_positions = [[] for _ in range(N)]
budgets = [1000] * N
quotas = {"QB": 2, "RB": 4, "WR" : 4, "TE" : 2, "K": 2, "DST": 2}

# calculating naive bid
def calc_bid(agent, player_id):
    return min((player_values[agent][player_id])/V * B, budgets[agent])

# calculating non-standard deviation strategic bid
def calc_strat_bid(agent, player_id, position, i, df):
    # calculate opportunity cost as the difference between the value of the player and the value of the next best player
    # find the next best player with position "position" after row i in df
    next_best_df = df[(df['Position'] == position) & (df['True Value'] < df.iloc[i]['True Value'])]
    # if next_best_df is empty: return value of player
    if next_best_df.empty:
        return calc_bid(agent, player_id)
    else:
        strategic_value = min(3*(df.iloc[i]['True Value']- next_best_df.iloc[0]['True Value']), budgets[agent])
        return strategic_value
    
# calculating standard deviation strategic bid
def calc_strat_new(agent, player_id, position, i, df):
    # get sub_dataframe of df of after row i
    sub_df = df.iloc[i:]
    # calculate standard deviations of true_values for each position in sub_df
    stds = sub_df.groupby('Position')['True Value'].std(ddof=0)
    prop = stds[position] / sum(stds)

    pos_df = sub_df[sub_df['Position'] == position]
    # if pos_df is empty: return value of player
    if pos_df.empty:
        return calc_bid(agent, player_id)
    else:
        strategic_value = min(prop*budgets[agent], budgets[agent])
        return strategic_value

# keeping track of current row in df_auction
cur_row = 0

# set of strategic agents
strat_agents = [0]

# iterate through df_auction
for row in df_auction.iterrows():
    pos = row[1]['Position']
    ids = row[1]['ID']
    bids = [0]*N # keep track of bids
    for i in range(N): # calculate bid for each player
        # if count of position in player_positions in greater than allotted number of players, then bid 0
        if player_positions[i].count(pos) >= quotas[pos]:
            bids[i] = -1
        else:
            if i in strat_agents:
                bids[i] = calc_strat_new(i, ids, pos, cur_row, df_auction)
            else:
                bids[i] = calc_bid(i, ids) # from paper: min of budget left & fair price

    # if no one can bid, goes to the one who nominated
    if sum(bids) == -4:
        winner = cur_row % 4
    else:
        winner = np.argmax(bids) # select player with highest bid
    # add player to player_selections
    print("Bids:", bids)
    # print("bid legnth", len(bids))
    # print(winner, row[1]['Player ID'])
    player_selections[winner].append(ids) # add selection to player_selections
    player_positions[winner].append(pos) # add position to player_positions
    budgets[winner] -= bids[winner] # add bid to budget
    cur_row += 1

    print("Player", winner, "selected", ids, "with bid", bids[winner], "and budget", budgets[winner])
    print("Drafted Player in Position", pos, "of value", player_values[winner][ids])
    print("")
# Out:
# Bids: [270.94631304148254, 138.07184376704512, 131.55452140390062, 139.3468779711543]
# Player 0 selected 0 with bid 270.94631304148254 and budget 729.0536869585175
# Drafted Player in Position QB of value 417.6199958724591
#
# Bids: [177.14338340119312, 132.37104020188957, 130.8301891683795, 128.14610806976782]
# Player 0 selected 1 with bid 177.14338340119312 and budget 551.9103035573244
# Drafted Player in Position QB of value 402.6531338388545
#
# Bids: [-1, 113.67701172629522, 122.94347556611497, 123.06257563085347]
# Player 3 selected 2 with bid 123.06257563085347 and budget 876.9374243691466
# Drafted Player in Position QB of value 389.7853254887745
#
# Bids: [-1, 111.28385498330358, 118.1298837527753, 125.03663155859915]
# Player 3 selected 3 with bid 125.03663155859915 and budget 751.9007928105474
# Drafted Player in Position QB of value 396.037900882918
#
# Bids: [-1, 101.26536304280152, 98.4787684660717, -1]
# Player 1 selected 4 with bid 101.26536304280152 and budget 898.7346369571985
# Drafted Player in Position QB of value 320.74537926769347
#
# Bids: [-1, 100.1775490649795, 91.88681042013022, -1]
# Player 1 selected 5 with bid 100.1775490649795 and budget 798.557087892219
# Drafted Player in Position QB of value 317.29986446968945
#
# Bids: [-1, -1, 95.33343191301628, -1]
# Player 2 selected 6 with bid 95.33343191301628 and budget 904.6665680869837
# Drafted Player in Position QB of value 301.95672890548997
#
# Bids: [-1, -1, 96.09881923448486, -1]
# Player 2 selected 7 with bid 96.09881923448486 and budget 808.5677488524989
# Drafted Player in Position QB of value 304.3809975728265
#
# Bids: [158.7466709256877, 85.27170004076063, 83.76723928257046, 91.10145295226742]
# Player 0 selected 12 with bid 158.7466709256877 and budget 393.1636326316367
# Drafted Player in Position RB of value 271.6930024065823
#
# Bids: [108.4374996591052, 87.86656374817741, 86.65549125162886, 86.35925284688741]
# Player 0 selected 13 with bid 108.4374996591052 and budget 284.7261329725315
# Drafted Player in Position RB of value 280.2334437907739
#
# Bids: [74.2224791238385, 80.61267140399261, 83.15599136702424, 82.85213370560835]
# Player 2 selected 14 with bid 83.15599136702424 and budget 725.4117574854746
# Drafted Player in Position RB of value 263.3862081561284
#
# Bids: [67.6692425602552, 85.65778684312959, 84.31270971141275, 84.47711837092642]
# Player 1 selected 15 with bid 85.65778684312959 and budget 712.8993010490894
# Drafted Player in Position RB of value 271.3103326022576
#
# Bids: [57.655560874337624, 83.353724110312, 80.29542977501931, 81.49099200461227]
# Player 1 selected 16 with bid 83.353724110312 and budget 629.5455769387775
# Drafted Player in Position RB of value 264.0125019038995
#
# Bids: [82.3455023107353, 77.84791969653058, 77.48326455768851, 78.06401867803982]
# Player 0 selected 19 with bid 82.3455023107353 and budget 202.3806306617962
# Drafted Player in Position WR of value 241.14877141578478
#
# Bids: [54.49622364574861, 73.88811399155465, 71.79684358185185, 78.14945155800375]
# Player 3 selected 22 with bid 78.14945155800375 and budget 673.7513412525436
# Drafted Player in Position WR of value 247.5286191285321
#
# Bids: [33.48131173859342, 71.54737924949622, 67.8066483475149, 75.17171758387197]
# Player 3 selected 24 with bid 75.17171758387197 and budget 598.5796236686716
# Drafted Player in Position RB of value 238.09701898221647
#
# Bids: [50.79928936850437, 70.18412637578692, 74.05652597071546, 70.54601234025229]
# Player 2 selected 25 with bid 74.05652597071546 and budget 651.3552315147591
# Drafted Player in Position WR of value 234.56478894649487
#
# Bids: [29.089918624084866, 71.50305687033735, 66.31882503160685, 67.86445651559914]
# Player 1 selected 26 with bid 71.50305687033735 and budget 558.0425200684401
# Drafted Player in Position RB of value 226.4769947546847
#
# Bids: [46.835996943337854, 63.11887478033906, 72.14304572693015, 66.07266371496847]
# Player 2 selected 28 with bid 72.14304572693015 and budget 579.212185787829
# Drafted Player in Position WR of value 228.5040794593354
#
# Bids: [42.00821650506696, 68.96982795351255, 65.1472652709133, 68.77005065462026]
# Player 1 selected 29 with bid 68.96982795351255 and budget 489.0726921149276
# Drafted Player in Position WR of value 218.45330881425681
#
# Bids: [27.830163010596568, 59.924864286313024, 68.97320307037586, 65.61284603005282]
# Player 2 selected 30 with bid 68.97320307037586 and budget 510.2389827174531
# Drafted Player in Position RB of value 218.46399907503172
#
# Bids: [81.5473300991247, 66.86992547815699, 65.2935398354106, 62.253351930418916]
# Player 0 selected 32 with bid 81.5473300991247 and budget 120.83330056267151
# Drafted Player in Position TE of value 197.80104421875075
#
# Bids: [16.6181042228221, 64.01918495151148, 61.57233766434372, 61.13234955108787]
# Player 1 selected 34 with bid 64.01918495151148 and budget 425.0535071634161
# Drafted Player in Position RB of value 202.77276593579367
#
# Bids: [14.667391348803381, -1, 63.3601111244774, 62.13167137911288]
# Player 2 selected 35 with bid 63.3601111244774 and budget 446.8788715929757
# Drafted Player in Position RB of value 200.68523197289161
#
# Bids: [26.212185919579067, 63.62359073498937, 63.16154391909999, 62.05717843479997]
# Player 1 selected 37 with bid 63.62359073498937 and budget 361.42991642842674
# Drafted Player in Position WR of value 201.51977070423695
#
# Bids: [11.911208771954891, -1, 59.39617272218941, 61.61178690912336]
# Player 3 selected 38 with bid 61.61178690912336 and budget 536.9678367595483
# Drafted Player in Position RB of value 195.1476335612846
#
# Bids: [39.72639863721269, 58.734036769858044, 55.997840187360076, 59.83586128553449]
# Player 3 selected 39 with bid 59.83586128553449 and budget 477.13197547401376
# Drafted Player in Position DST of value 189.5226111392698
#
# Bids: [22.087816516541782, 55.28793594332548, 60.40026613942234, 58.600013739255374]
# Player 2 selected 40 with bid 60.40026613942234 and budget 386.47860545355337
# Drafted Player in Position WR of value 191.31029296335285
#
# Bids: [10.495356030492028, -1, 54.812918896397264, 55.283270986691655]
# Player 3 selected 42 with bid 55.283270986691655 and budget 421.8487044873221
# Drafted Player in Position RB of value 175.10285044147247
#
# Bids: [10.01751888150013, -1, 59.90864025406997, 55.07584082278995]
# Player 2 selected 44 with bid 59.90864025406997 and budget 326.5699651994834
# Drafted Player in Position RB of value 189.75312942473488
#
# Bids: [9.647118225770333, -1, -1, 57.51761901575116]
# Player 3 selected 45 with bid 57.51761901575116 and budget 364.33108547157093
# Drafted Player in Position RB of value 182.17986853001483
#
# Bids: [6.550925707542324, -1, -1, -1]
# Player 0 selected 46 with bid 6.550925707542324 and budget 114.28237485512919
# Drafted Player in Position RB of value 176.4792075403502
#
# Bids: [0.0, -1, -1, -1]
# Player 0 selected 48 with bid 0.0 and budget 114.28237485512919
# Drafted Player in Position RB of value 161.45137189230792
#
# Bids: [38.196339897060625, 52.798223285626406, 48.20544453675929, 54.86275527698571]
# Player 3 selected 49 with bid 54.86275527698571 and budget 309.46833019458523
# Drafted Player in Position DST of value 173.77091949544263
#
# Bids: [15.493462959577089, 48.673048298633674, 51.16886761112341, 51.53571727667779]
# Player 3 selected 50 with bid 51.53571727667779 and budget 257.9326129179075
# Drafted Player in Position WR of value 163.2329425092173
#
# Bids: [19.37169069014859, 50.91032777961459, 50.39676245045072, 52.21409279353488]
# Player 3 selected 55 with bid 52.21409279353488 and budget 205.7185201243726
# Drafted Player in Position K of value 165.38161216192253
#
# Bids: [36.51875209876989, 47.788888472709296, 52.01420356050104, -1]
# Player 2 selected 56 with bid 52.01420356050104 and budget 274.5557616389824
# Drafted Player in Position DST of value 164.74848800244197
#
# Bids: [19.26388562416215, 49.315488519651815, 51.76496594437068, 53.33777869872313]
# Player 3 selected 57 with bid 53.33777869872313 and budget 152.38074142564946
# Drafted Player in Position K of value 168.94074680586817
#
# Bids: [12.556748650900863, 50.8945541192503, 50.53999818152285, 51.28809574079125]
# Player 3 selected 58 with bid 51.28809574079125 and budget 101.09264568485821
# Drafted Player in Position WR of value 162.44863224698867
#
# Bids: [18.195324879201817, 50.86738264578786, 52.87597205087371, -1]
# Player 2 selected 59 with bid 52.87597205087371 and budget 221.6797895881087
# Drafted Player in Position K of value 167.47803197463614
#
# Bids: [11.351120379032702, 49.972146410861676, 51.532095500173256, 48.332320170281676]
# Player 2 selected 60 with bid 51.532095500173256 and budget 170.14769408793543
# Drafted Player in Position WR of value 163.22147098486127
#
# Bids: [15.593192049046602, 47.523531053667085, 48.58004646124933, -1]
# Player 2 selected 61 with bid 48.58004646124933 and budget 121.5676476266861
# Drafted Player in Position K of value 153.8712246601996
#
# Bids: [10.43365971640077, 51.8349887570243, -1, 50.54352838480353]
# Player 1 selected 63 with bid 51.8349887570243 and budget 309.59492767140244
# Drafted Player in Position WR of value 164.18084751427983
#
# Bids: [8.22670504979734, 55.377747147479404, -1, 47.04201376390529]
# Player 1 selected 64 with bid 55.377747147479404 and budget 254.21718052392305
# Drafted Player in Position WR of value 175.40209187124756
#
# Bids: [6.402523349126501, -1, -1, 50.72864395437099]
# Player 3 selected 68 with bid 50.72864395437099 and budget 50.364001730487225
# Drafted Player in Position WR of value 160.6766386449758
#
# Bids: [39.250764598718035, 51.07231720701733, 49.373077011374846, -1]
# Player 1 selected 71 with bid 51.07231720701733 and budget 203.1448633169057
# Drafted Player in Position DST of value 161.7651807135765
#
# Bids: [5.172432818705511, -1, -1, -1]
# Player 0 selected 70 with bid 5.172432818705511 and budget 109.10994203642367
# Drafted Player in Position WR of value 147.7939790214787
#
# Bids: [8.870655162018483, 47.2804716468704, -1, -1]
# Player 1 selected 69 with bid 47.2804716468704 and budget 155.8643916700353
# Drafted Player in Position K of value 149.75498388250614
#
# Bids: [39.97361130581871, 47.490047246086064, 48.68630356207317, -1]
# Player 2 selected 72 with bid 48.68630356207317 and budget 72.88134406461293
# Drafted Player in Position DST of value 154.2077807449215
#
# Bids: [2.9163482321062593, -1, -1, -1]
# Player 0 selected 73 with bid 2.9163482321062593 and budget 106.19359380431742
# Drafted Player in Position WR of value 152.12627281648065
#
# Bids: [0.0, -1, -1, -1]
# Player 0 selected 74 with bid 0.0 and budget 106.19359380431742
# Drafted Player in Position WR of value 143.57551644731058
#
# Bids: [0.0, 45.20492603250711, -1, -1]
# Player 1 selected 78 with bid 45.20492603250711 and budget 110.6594656375282
# Drafted Player in Position K of value 143.1809525922122
#
# Bids: [0.0, -1, -1, -1]
# Player 0 selected 77 with bid 0.0 and budget 106.19359380431742
# Drafted Player in Position K of value 140.98128592369673
#
# Bids: [0.0, -1, -1, -1]
# Player 0 selected 76 with bid 0.0 and budget 106.19359380431742
# Drafted Player in Position K of value 148.89712780166565
#
# Bids: [74.58647086772285, 44.07602053903105, 42.35227553664854, 43.98562510123967]
# Player 0 selected 84 with bid 74.58647086772285 and budget 31.607122936594564
# Drafted Player in Position TE of value 136.11947461486048
#
# Bids: [10.04115585795063, 44.51351524705522, -1, -1]
# Player 1 selected 89 with bid 44.51351524705522 and budget 66.14595039047299
# Drafted Player in Position DST of value 140.99099535564153
#
# Bids: [-1, 44.182008748954196, 42.91775288958964, 40.740512356505086]
# Player 1 selected 95 with bid 44.182008748954196 and budget 21.963941641518794
# Drafted Player in Position TE of value 139.9409899612188
#
# Bids: [10.275596309845467, -1, -1, -1]
# Player 0 selected 101 with bid 10.275596309845467 and budget 21.331526626749095
# Drafted Player in Position DST of value 135.451657105502
#
# Bids: [-1, 21.963941641518794, 44.90003912550255, 40.30003995406591]
# Player 2 selected 110 with bid 44.90003912550255 and budget 27.98130493911038
# Drafted Player in Position TE of value 142.21526142513864
#
# Bids: [0.0, -1, -1, -1]
# Player 0 selected 122 with bid 0.0 and budget 21.331526626749095
# Drafted Player in Position DST of value 123.27386554150615
#
# Bids: [-1, 21.963941641518794, 27.98130493911038, 38.22941625382659]
# Player 3 selected 132 with bid 38.22941625382659 and budget 12.134585476660632
# Drafted Player in Position TE of value 121.086897306964
#
# Bids: [-1, 21.963941641518794, 27.98130493911038, 12.134585476660632]
# Player 2 selected 168 with bid 27.98130493911038 and budget 0.0
# Drafted Player in Position TE of value 99.71247600774996
#
# Bids: [-1, 21.963941641518794, -1, 12.134585476660632]
# Player 1 selected 177 with bid 21.963941641518794 and budget 0.0
# Drafted Player in Position TE of value 97.67824304522547
#
# Bids: [-1, -1, -1, 12.134585476660632]
# Player 3 selected 187 with bid 12.134585476660632 and budget 0.0
# Drafted Player in Position TE of value 99.01778912121875

# %%
# print results

for (i, selection) in enumerate(player_selections):
    print("Player", i, "selections:", selection)

print("")

for (i, position) in enumerate(player_positions):
    print("Player", i, "positions:", position)
# Out:
# Player 0 selections: [0, 1, 12, 13, 19, 32, 46, 48, 70, 73, 74, 77, 76, 84, 101, 122]
# Player 1 selections: [4, 5, 15, 16, 26, 29, 34, 37, 63, 64, 71, 69, 78, 89, 95, 177]
# Player 2 selections: [6, 7, 14, 25, 28, 30, 35, 40, 44, 56, 59, 60, 61, 72, 110, 168]
# Player 3 selections: [2, 3, 22, 24, 38, 39, 42, 45, 49, 50, 55, 57, 58, 68, 132, 187]
#
# Player 0 positions: ['QB', 'QB', 'RB', 'RB', 'WR', 'TE', 'RB', 'RB', 'WR', 'WR', 'WR', 'K', 'K', 'TE', 'DST', 'DST']
# Player 1 positions: ['QB', 'QB', 'RB', 'RB', 'RB', 'WR', 'RB', 'WR', 'WR', 'WR', 'DST', 'K', 'K', 'DST', 'TE', 'TE']
# Player 2 positions: ['QB', 'QB', 'RB', 'WR', 'WR', 'RB', 'RB', 'WR', 'RB', 'DST', 'K', 'WR', 'K', 'DST', 'TE', 'TE']
# Player 3 positions: ['QB', 'QB', 'WR', 'RB', 'RB', 'DST', 'RB', 'RB', 'DST', 'WR', 'K', 'K', 'WR', 'WR', 'TE', 'TE']

# %%
# print true values for each of the selections
for i in range(N):
    print("Player", i, "selections:")
    print(player_selections[i])
    print([df_auction.loc[df_auction['ID'] == j]['True Value'].values[0] for j in player_selections[i]])
    print("Total value:", sum(df_auction.loc[df_auction['ID'].isin(player_selections[i])]['True Value'].values))
# Out:
# Player 0 selections:
# [0, 1, 12, 13, 19, 32, 46, 48, 70, 73, 74, 77, 76, 84, 101, 122]
# [428.4, 412.2, 275.3, 271.4, 240.7, 206.3, 175.5, 170.1, 152.0, 149.8, 148.4, 146.0, 146.0, 140.5, 134.0, 121.0]
# Total value: 3317.6
# Player 1 selections:
# [4, 5, 15, 16, 26, 29, 34, 37, 63, 64, 71, 69, 78, 89, 95, 177]
# [314.9, 307.0, 265.7, 254.4, 213.9, 211.2, 198.8, 194.6, 157.9, 155.4, 152.0, 152.0, 146.0, 139.0, 136.8, 97.3]
# Total value: 3096.9000000000005
# Player 2 selections:
# [6, 7, 14, 25, 28, 30, 35, 40, 44, 56, 59, 60, 61, 72, 110, 168]
# [305.6, 303.6, 269.8, 222.2, 211.6, 209.8, 196.7, 184.2, 180.7, 163.0, 161.0, 159.6, 159.0, 151.0, 129.4, 103.9]
# Total value: 3111.1
# Player 3 selections:
# [2, 3, 22, 24, 38, 39, 42, 45, 49, 50, 55, 57, 58, 68, 132, 187]
# [384.0, 369.0, 235.5, 227.0, 189.6, 186.0, 182.5, 180.1, 170.0, 169.0, 164.0, 162.0, 161.6, 153.3, 117.5, 92.8]
# Total value: 3143.9

# %%
# calculate social welfare using normalized values

# sum of all true values in df_auction
true_value = df_auction['True Value'].sum()

# calculate social welfare for each player as sum of their perceived values divided by the sum of all true values
for player in range(N):
    sum_perceived = [player_values[player][j] for j in player_selections[player]]
    print("Player", player, "social welfare:", sum(sum_perceived)/true_value)

print("Sum of social welfares:", sum([sum([player_values[player][j] for j in player_selections[player]])/true_value for player in range(N)]))
# Out:
# Player 0 social welfare: 0.2586762816408196
# Player 1 social welfare: 0.25221873028836345
# Player 2 social welfare: 0.2508749508880567
# Player 3 social welfare: 0.2547817993170276
# Sum of social welfares: 1.0165517621342675

# %%
# print the sample standard deviation of the true values for each position
print(df_auction.groupby('Position')['True Value'].std(ddof=0))
# Out:
# Position
# DST    19.544820
# K       7.348469
# QB     48.297863
# RB     37.380087
# TE     33.983633
# WR     31.701338
# Name: True Value, dtype: float64
